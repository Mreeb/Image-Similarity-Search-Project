# %% [markdown]
# # COMBINING DATA

# %% [markdown]
# USE ONLY WHEN NEEDED TO COMBINE THE FILES

# %%
# import pandas as pd
# import glob

# # Get a list of all Excel files with the specified naming pattern
# dc_files = glob.glob("dc-main-series_*.xlsx")
# image_files = glob.glob("image-main-series_*.xlsx")

# # Initialize an empty DataFrame to store merged data
# merged_data = pd.DataFrame()

# for file in dc_files:
#     df = pd.read_excel(file)
#     merged_data = merged_data.append(df, ignore_index=True)

# for file in image_files:
#     df = pd.read_excel(file)
#     merged_data = merged_data.append(df, ignore_index=True)
# merged_data.to_excel("merged_file.xlsx", index=False)

# %%
data = pd.read_excel("merged_file.xlsx")
data
# Out:
#                                         series_title issue_number  \
# 0      Batman: Battle For The Cowl - The Underground           #1
# 1                          Flashpoint: Reverse-Flash           #1
# 2        Green Lantern / Sentinel: Heart Of Darkness           #1
# 3        Green Lantern / Sentinel: Heart Of Darkness           #2
# 4        Green Lantern / Sentinel: Heart Of Darkness           #3
# ...                                              ...          ...
# 59858                          Fishflies (Fcbd 2023)           #1
# 59859                                      Ophiuchus           #1
# 59860                      Street Angel Vs Ninjatech           #1
# 59861                                  Me The People           #1
# 59862      Hack/Slash Deluxe Edition: The Crossovers           #1
#
#       issue_comments issue_edition       published_date   comic_era  \
# 0                NaN           NaN  2009-06-01 00:00:00  Modern Age
# 1                NaN           NaN  2011-08-01 00:00:00  Modern Age
# 2                NaN           NaN  1998-03-01 00:00:00  Modern Age
# 3                NaN           NaN  1998-04-01 00:00:00  Modern Age
# 4                NaN           NaN  1998-05-01 00:00:00  Modern Age
# ...              ...           ...                  ...         ...
# 59858            NaN           NaN         2023-Current  Modern Age
# 59859            NaN           NaN                 2019  Modern Age
# 59860            NaN           NaN                 2018  Modern Age
# 59861            NaN           NaN                 2018  Modern Age
# 59862            NaN           NaN  2022-10-01 00:00:00  Modern Age
#
#                                              issue_image  \
# 0      https://comicspriceguide.com/image/ulstm/wowvi...
# 1      https://comicspriceguide.com/image/tluvh/yhwth...
# 2      https://comicspriceguide.com/image/pivvh/pbxwn...
# 3      https://comicspriceguide.com/image/pivvh/pbxwn...
# 4      https://comicspriceguide.com/image/pivvh/pbxwn...
# ...                                                  ...
# 59858  https://comicspriceguide.com/image/phuwby/piqx...
# 59859  https://comicspriceguide.com/image/pkspip/pkwvcxp
# 59860  https://comicspriceguide.com/image/pjxxny/pkutiqq
# 59861  https://comicspriceguide.com/image/pjxwmq/pkuriuu
# 59862  https://comicspriceguide.com/image/phstkv/phyr...
#
#                                          issue_image_url
# 0        https://comicspriceguide.com/image/ulstm/wowvix
# 1        https://comicspriceguide.com/image/tluvh/yhwthw
# 2        https://comicspriceguide.com/image/pivvh/pbxwnw
# 3        https://comicspriceguide.com/image/pivvh/pbxwnv
# 4        https://comicspriceguide.com/image/pivvh/pbxwny
# ...                                                  ...
# 59858  https://comicspriceguide.com/image/phuwby/piqxiqs
# 59859  https://comicspriceguide.com/image/pkspip/pkwvcxp
# 59860  https://comicspriceguide.com/image/pjxxny/pkutiqq
# 59861  https://comicspriceguide.com/image/pjxwmq/pkuriuu
# 59862  https://comicspriceguide.com/image/phstkv/phyrisv
#
# [59863 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# series_title           0
# issue_number           0
# issue_comments     39426
# issue_edition      45210
# published_date         0
# comic_era              0
# issue_image            0
# issue_image_url        0
# dtype: int64

# %%
data.describe()
# Out:
#        series_title issue_number                         issue_comments  \
# count         59863        59863                                  20437
# unique         2895         5512                                  12008
# top          Batman           #1  Polybagged Digital Combo Pack Variant
# freq           2089         2916                                    286
#
#          issue_edition published_date   comic_era  \
# count            14653          59863       59863
# unique               3           1506           5
# top     DIRECT EDITION      1952-1977  Modern Age
# freq              8252            240       39143
#
#                                              issue_image  \
# count                                              59863
# unique                                             59304
# top     https://comicspriceguide.com/img/missing_thm.jpg
# freq                                                 477
#
#                                          issue_image_url
# count                                              59863
# unique                                             59304
# top     https://comicspriceguide.com/img/missing_lrg.jpg
# freq                                                 477

# %%
duplicate_rows = data[data.duplicated()]
data = data.drop_duplicates()
# Out:
#                                         series_title issue_number  \
# 0      Batman: Battle For The Cowl - The Underground           #1
# 1                          Flashpoint: Reverse-Flash           #1
# 2        Green Lantern / Sentinel: Heart Of Darkness           #1
# 3        Green Lantern / Sentinel: Heart Of Darkness           #2
# 4        Green Lantern / Sentinel: Heart Of Darkness           #3
# ...                                              ...          ...
# 59858                          Fishflies (Fcbd 2023)           #1
# 59859                                      Ophiuchus           #1
# 59860                      Street Angel Vs Ninjatech           #1
# 59861                                  Me The People           #1
# 59862      Hack/Slash Deluxe Edition: The Crossovers           #1
#
#       issue_comments issue_edition       published_date   comic_era  \
# 0                NaN           NaN  2009-06-01 00:00:00  Modern Age
# 1                NaN           NaN  2011-08-01 00:00:00  Modern Age
# 2                NaN           NaN  1998-03-01 00:00:00  Modern Age
# 3                NaN           NaN  1998-04-01 00:00:00  Modern Age
# 4                NaN           NaN  1998-05-01 00:00:00  Modern Age
# ...              ...           ...                  ...         ...
# 59858            NaN           NaN         2023-Current  Modern Age
# 59859            NaN           NaN                 2019  Modern Age
# 59860            NaN           NaN                 2018  Modern Age
# 59861            NaN           NaN                 2018  Modern Age
# 59862            NaN           NaN  2022-10-01 00:00:00  Modern Age
#
#                                              issue_image  \
# 0      https://comicspriceguide.com/image/ulstm/wowvi...
# 1      https://comicspriceguide.com/image/tluvh/yhwth...
# 2      https://comicspriceguide.com/image/pivvh/pbxwn...
# 3      https://comicspriceguide.com/image/pivvh/pbxwn...
# 4      https://comicspriceguide.com/image/pivvh/pbxwn...
# ...                                                  ...
# 59858  https://comicspriceguide.com/image/phuwby/piqx...
# 59859  https://comicspriceguide.com/image/pkspip/pkwvcxp
# 59860  https://comicspriceguide.com/image/pjxxny/pkutiqq
# 59861  https://comicspriceguide.com/image/pjxwmq/pkuriuu
# 59862  https://comicspriceguide.com/image/phstkv/phyr...
#
#                                          issue_image_url
# 0        https://comicspriceguide.com/image/ulstm/wowvix
# 1        https://comicspriceguide.com/image/tluvh/yhwthw
# 2        https://comicspriceguide.com/image/pivvh/pbxwnw
# 3        https://comicspriceguide.com/image/pivvh/pbxwnv
# 4        https://comicspriceguide.com/image/pivvh/pbxwny
# ...                                                  ...
# 59858  https://comicspriceguide.com/image/phuwby/piqxiqs
# 59859  https://comicspriceguide.com/image/pkspip/pkwvcxp
# 59860  https://comicspriceguide.com/image/pjxxny/pkutiqq
# 59861  https://comicspriceguide.com/image/pjxwmq/pkuriuu
# 59862  https://comicspriceguide.com/image/phstkv/phyrisv
#
# [59863 rows x 8 columns]

# %% [markdown]
# # CLEAN IMAGE URLs

# %%
# image_urls = data['issue_image_url']
# data['image_download_error'] = False
# for i, url in enumerate(image_urls):
#     try:
#         req = urllib.request.urlopen(url)
#         arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
#         img = cv2.imdecode(arr, -1)
#     except:
#         data.loc[i, 'image_download_error'] = True
# data = data[data['image_download_error'] == False].drop(columns='image_download_error')

# %% [markdown]
# # UPDATED

# %%
import pandas as pd
import urllib.request
import numpy as np
import cv2
import os
from sklearn.feature_extraction import image
from sklearn.neighbors import NearestNeighbors
import tensorflow as tf
import tensorflow_hub as hub

# %%
# Load the CSV file
excel_file_path = "merged_file.xlsx"
data = pd.read_excel(excel_file_path)

# Get the image URLs and details from the Excel
image_urls = data['issue_image_url']
image_attributes = data[['series_title', 'issue_number', 'issue_comments', 'issue_edition', 'published_date', 'comic_era', 'issue_image', 'issue_image_url']]

# %%
def preprocess_images(image_urls, image_attributes, save_directory):
    images = []
    filenames = []
    image_paths = []

    dropped_rows = []

    for i, url in enumerate(image_urls):
        try:
            req = urllib.request.urlopen(url)
            arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
            img = cv2.imdecode(arr, -1)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            filename = str(i+1)
            filenames.append(filename)
            image_path = os.path.join(save_directory, f"preprocessed_{filename}.jpg")
            cv2.imwrite(image_path, img)
            image_paths.append(image_path)
            print(f"Downloaded and processed image {i+1} of {len(image_urls)}")
        except:
            print(f"Error downloading image {i+1}")
            dropped_rows.append(i)

    # Drop rows with image download errors
    image_urls = image_urls.drop(dropped_rows)
    image_attributes = image_attributes.drop(dropped_rows)

    # Create a DataFrame with image details
    image_details = pd.DataFrame({
        'Filename': filenames,
        'Image_Path': image_paths
    })
    image_details = pd.concat([image_details, image_attributes], axis=1)

    # Save image details to a CSV file
    csv_path = os.path.join(save_directory, 'Final.csv')
    image_details.to_csv(csv_path, index=False)
    print(f"Preprocessed image details saved to: {csv_path}")

    return images, filenames, image_paths, image_urls, image_attributes

# import os

# def preprocess_images(image_urls, image_attributes, save_directory):
#     images = []
#     filenames = []
#     image_paths = []

#     dropped_rows = []

#     for i, url in enumerate(image_urls):
#         try:
#             req = urllib.request.urlopen(url)
#             arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
#             img = cv2.imdecode(arr, -1)
#             img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#             img = cv2.resize(img, (224, 224))
#             filename = str(i+1)
#             filenames.append(filename)
#             image_path = os.path.join(save_directory, f"preprocessed_{filename}.jpg")
#             cv2.imwrite(image_path, img)
#             image_paths.append(image_path)
#             print(f"Downloaded and processed image {i+1} of {len(image_urls)}")
#         except:
#             print(f"Error downloading image {i+1}")
#             dropped_rows.append(i)

#     # Drop rows with image download errors
#     image_urls = image_urls.drop(dropped_rows)
#     image_attributes = image_attributes.drop(dropped_rows)

#     # Create a DataFrame with image details
#     image_details = pd.DataFrame({
#         'Filename': filenames,
#         'Image_Path': image_paths,
#         'issue_image_url': image_urls,
#         'issue_image': image_attributes['issue_image'],
#         'series_title': image_attributes['series_title'],
#         'issue_number': image_attributes['issue_number'],
#         'issue_comments': image_attributes['issue_comments'],
#         'issue_edition': image_attributes['issue_edition'],
#         'published_date': image_attributes['published_date'],
#         'comic_era': image_attributes['comic_era']
#     })

#     # Save image details to a CSV file
#     csv_path = os.path.join(save_directory, 'preprocessed_images.csv')
#     image_details.to_csv(csv_path, index=False)
#     print(f"Preprocessed image details saved to: {csv_path}")

#     return image_details

# %%
# Specify the directory to save the preprocessed images and CSV file
save_directory = "Final"

# Create the save directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Download and preprocess the database images, and save details to CSV
images, filenames, image_paths, image_urls, image_attributes = preprocess_images(image_urls, image_attributes, save_directory)
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloaded and processed image 54865 of 59863
# Downloaded and processed image 54866 of 59863
# Downloaded and processed image 54867 of 59863
# Downloaded and processed image 54868 of 59863
# Downloaded and processed image 54869 of 59863
# Downloaded and processed image 54870 of 59863
# Downloaded and processed image 54871 of 59863
# Downloaded and processed image 54872 of 59863
# Downloaded and processed image 54873 of 59863
# Downloaded and processed image 54874 of 59863
# Downloaded and processed image 54875 of 59863
# Downloaded and processed image 54876 of 59863
# Downloaded and processed image 54877 of 59863
# Downloaded and processed image 54878 of 59863
# Downloaded and processed image 54879 of 59863
# Downloaded and processed image 54880 of 59863
# Downloaded and processed image 54881 of 59863
# Downloaded and processed image 54882 of 59863
# Downloaded and processed image 54883 of 59863
# Downloaded and processed image 54884 of 59863
# Downloaded and processed image 54885 of 59863
# Downloaded and processed image 54886 of 59863
# Downloaded and processed image 54887 of 59863
# Downloaded and processed image 54888 of 59863
# Downloaded and processed image 54889 of 59863
# Downloaded and processed image 54890 of 59863
# Downloaded and processed image 54891 of 59863
# Downloaded and processed image 54892 of 59863
# Downloaded and processed image 54893 of 59863
# Downloaded and processed image 54894 of 59863
# Downloaded and processed image 54895 of 59863
# Downloaded and processed image 54896 of 59863
# Downloaded and processed image 54897 of 59863
# Downloaded and processed image 54898 of 59863
# Downloaded and processed image 54899 of 59863
# Downloaded and processed image 54900 of 59863
# Downloaded and processed image 54901 of 59863
# Downloaded and processed image 54902 of 59863
# Downloaded and processed image 54903 of 59863
# Downloaded and processed image 54904 of 59863
# Downloaded and processed image 54905 of 59863
# Downloaded and processed image 54906 of 59863
# Downloaded and processed image 54907 of 59863
# Downloaded and processed image 54908 of 59863
# Downloaded and processed image 54909 of 59863
# Downloaded and processed image 54910 of 59863
# Downloaded and processed image 54911 of 59863
# Downloaded and processed image 54912 of 59863
# Downloaded and processed image 54913 of 59863
# Downloaded and processed image 54914 of 59863
# Downloaded and processed image 54915 of 59863
# Downloaded and processed image 54916 of 59863
# Downloaded and processed image 54917 of 59863
# Downloaded and processed image 54918 of 59863
# Downloaded and processed image 54919 of 59863
# Downloaded and processed image 54920 of 59863
# Downloaded and processed image 54921 of 59863
# Downloaded and processed image 54922 of 59863
# Downloaded and processed image 54923 of 59863
# Downloaded and processed image 54924 of 59863
# Downloaded and processed image 54925 of 59863
# Downloaded and processed image 54926 of 59863
# Downloaded and processed image 54927 of 59863
# Downloaded and processed image 54928 of 59863
# Downloaded and processed image 54929 of 59863
# Downloaded and processed image 54930 of 59863
# Downloaded and processed image 54931 of 59863
# Downloaded and processed image 54932 of 59863
# Downloaded and processed image 54933 of 59863
# Downloaded and processed image 54934 of 59863
# Downloaded and processed image 54935 of 59863
# Downloaded and processed image 54936 of 59863
# Downloaded and processed image 54937 of 59863
# Downloaded and processed image 54938 of 59863
# Downloaded and processed image 54939 of 59863
# Downloaded and processed image 54940 of 59863
# Downloaded and processed image 54941 of 59863
# Downloaded and processed image 54942 of 59863
# Downloaded and processed image 54943 of 59863
# Downloaded and processed image 54944 of 59863
# Downloaded and processed image 54945 of 59863
# Downloaded and processed image 54946 of 59863
# Downloaded and processed image 54947 of 59863
# Downloaded and processed image 54948 of 59863
# Downloaded and processed image 54949 of 59863
# Downloaded and processed image 54950 of 59863
# Downloaded and processed image 54951 of 59863
# Downloaded and processed image 54952 of 59863
# Downloaded and processed image 54953 of 59863
# Downloaded and processed image 54954 of 59863
# Downloaded and processed image 54955 of 59863
# Downloaded and processed image 54956 of 59863
# Downloaded and processed image 54957 of 59863
# Downloaded and processed image 54958 of 59863
# Downloaded and processed image 54959 of 59863
# Downloaded and processed image 54960 of 59863
# Downloaded and processed image 54961 of 59863
# Downloaded and processed image 54962 of 59863
# Downloaded and processed image 54963 of 59863
# Downloaded and processed image 54964 of 59863
# Downloaded and processed image 54965 of 59863
# Downloaded and processed image 54966 of 59863
# Downloaded and processed image 54967 of 59863
# Downloaded and processed image 54968 of 59863
# Downloaded and processed image 54969 of 59863
# Downloaded and processed image 54970 of 59863
# Downloaded and processed image 54971 of 59863
# Downloaded and processed image 54972 of 59863
# Downloaded and processed image 54973 of 59863
# Downloaded and processed image 54974 of 59863
# Downloaded and processed image 54975 of 59863
# Downloaded and processed image 54976 of 59863
# Downloaded and processed image 54977 of 59863
# Downloaded and processed image 54978 of 59863
# Downloaded and processed image 54979 of 59863
# Downloaded and processed image 54980 of 59863
# Downloaded and processed image 54981 of 59863
# Downloaded and processed image 54982 of 59863
# Downloaded and processed image 54983 of 59863
# Downloaded and processed image 54984 of 59863
# Downloaded and processed image 54985 of 59863
# Downloaded and processed image 54986 of 59863
# Downloaded and processed image 54987 of 59863
# Downloaded and processed image 54988 of 59863
# Downloaded and processed image 54989 of 59863
# Downloaded and processed image 54990 of 59863
# Downloaded and processed image 54991 of 59863
# Downloaded and processed image 54992 of 59863
# Downloaded and processed image 54993 of 59863
# Downloaded and processed image 54994 of 59863
# Downloaded and processed image 54995 of 59863
# Downloaded and processed image 54996 of 59863
# Downloaded and processed image 54997 of 59863
# Downloaded and processed image 54998 of 59863
# Downloaded and processed image 54999 of 59863
# Downloaded and processed image 55000 of 59863
# Downloaded and processed image 55001 of 59863
# Downloaded and processed image 55002 of 59863
# Downloaded and processed image 55003 of 59863
# Downloaded and processed image 55004 of 59863
# Downloaded and processed image 55005 of 59863
# Downloaded and processed image 55006 of 59863
# Downloaded and processed image 55007 of 59863
# Downloaded and processed image 55008 of 59863
# Downloaded and processed image 55009 of 59863
# Downloaded and processed image 55010 of 59863
# Downloaded and processed image 55011 of 59863
# Downloaded and processed image 55012 of 59863
# Downloaded and processed image 55013 of 59863
# Downloaded and processed image 55014 of 59863
# Downloaded and processed image 55015 of 59863
# Downloaded and processed image 55016 of 59863
# Downloaded and processed image 55017 of 59863
# Downloaded and processed image 55018 of 59863
# Downloaded and processed image 55019 of 59863
# Downloaded and processed image 55020 of 59863
# Downloaded and processed image 55021 of 59863
# Downloaded and processed image 55022 of 59863
# Downloaded and processed image 55023 of 59863
# Downloaded and processed image 55024 of 59863
# Downloaded and processed image 55025 of 59863
# Downloaded and processed image 55026 of 59863
# Downloaded and processed image 55027 of 59863
# Downloaded and processed image 55028 of 59863
# Downloaded and processed image 55029 of 59863
# Downloaded and processed image 55030 of 59863
# Downloaded and processed image 55031 of 59863
# Downloaded and processed image 55032 of 59863
# Downloaded and processed image 55033 of 59863
# Downloaded and processed image 55034 of 59863
# Downloaded and processed image 55035 of 59863
# Downloaded and processed image 55036 of 59863
# Downloaded and processed image 55037 of 59863
# Downloaded and processed image 55038 of 59863
# Downloaded and processed image 55039 of 59863
# Downloaded and processed image 55040 of 59863
# Downloaded and processed image 55041 of 59863
# Downloaded and processed image 55042 of 59863
# Downloaded and processed image 55043 of 59863
# Downloaded and processed image 55044 of 59863
# Downloaded and processed image 55045 of 59863
# Downloaded and processed image 55046 of 59863
# Downloaded and processed image 55047 of 59863
# Downloaded and processed image 55048 of 59863
# Downloaded and processed image 55049 of 59863
# Downloaded and processed image 55050 of 59863
# Downloaded and processed image 55051 of 59863
# Downloaded and processed image 55052 of 59863
# Downloaded and processed image 55053 of 59863
# Downloaded and processed image 55054 of 59863
# Downloaded and processed image 55055 of 59863
# Downloaded and processed image 55056 of 59863
# Downloaded and processed image 55057 of 59863
# Downloaded and processed image 55058 of 59863
# Downloaded and processed image 55059 of 59863
# Downloaded and processed image 55060 of 59863
# Downloaded and processed image 55061 of 59863
# Downloaded and processed image 55062 of 59863
# Downloaded and processed image 55063 of 59863
# Downloaded and processed image 55064 of 59863
# Downloaded and processed image 55065 of 59863
# Downloaded and processed image 55066 of 59863
# Downloaded and processed image 55067 of 59863
# Downloaded and processed image 55068 of 59863
# Downloaded and processed image 55069 of 59863
# Downloaded and processed image 55070 of 59863
# Downloaded and processed image 55071 of 59863
# Downloaded and processed image 55072 of 59863
# Downloaded and processed image 55073 of 59863
# Downloaded and processed image 55074 of 59863
# Downloaded and processed image 55075 of 59863
# Downloaded and processed image 55076 of 59863
# Downloaded and processed image 55077 of 59863
# Downloaded and processed image 55078 of 59863
# Downloaded and processed image 55079 of 59863
# Downloaded and processed image 55080 of 59863
# Downloaded and processed image 55081 of 59863
# Downloaded and processed image 55082 of 59863
# Downloaded and processed image 55083 of 59863
# Downloaded and processed image 55084 of 59863
# Downloaded and processed image 55085 of 59863
# Downloaded and processed image 55086 of 59863
# Downloaded and processed image 55087 of 59863
# Downloaded and processed image 55088 of 59863
# Downloaded and processed image 55089 of 59863
# Downloaded and processed image 55090 of 59863
# Downloaded and processed image 55091 of 59863
# Downloaded and processed image 55092 of 59863
# Downloaded and processed image 55093 of 59863
# Downloaded and processed image 55094 of 59863
# Downloaded and processed image 55095 of 59863
# Downloaded and processed image 55096 of 59863
# Downloaded and processed image 55097 of 59863
# Downloaded and processed image 55098 of 59863
# Downloaded and processed image 55099 of 59863
# Downloaded and processed image 55100 of 59863
# Downloaded and processed image 55101 of 59863
# Downloaded and processed image 55102 of 59863
# Downloaded and processed image 55103 of 59863
# Downloaded and processed image 55104 of 59863
# Downloaded and processed image 55105 of 59863
# Downloaded and processed image 55106 of 59863
# Downloaded and processed image 55107 of 59863
# Downloaded and processed image 55108 of 59863
# Downloaded and processed image 55109 of 59863
# Downloaded and processed image 55110 of 59863
# Downloaded and processed image 55111 of 59863
# Downloaded and processed image 55112 of 59863
# Downloaded and processed image 55113 of 59863
# Downloaded and processed image 55114 of 59863
# Downloaded and processed image 55115 of 59863
# Downloaded and processed image 55116 of 59863
# Downloaded and processed image 55117 of 59863
# Downloaded and processed image 55118 of 59863
# Downloaded and processed image 55119 of 59863
# Downloaded and processed image 55120 of 59863
# Downloaded and processed image 55121 of 59863
# Downloaded and processed image 55122 of 59863
# Downloaded and processed image 55123 of 59863
# Downloaded and processed image 55124 of 59863
# Downloaded and processed image 55125 of 59863
# Downloaded and processed image 55126 of 59863
# Downloaded and processed image 55127 of 59863
# Downloaded and processed image 55128 of 59863
# Downloaded and processed image 55129 of 59863
# Downloaded and processed image 55130 of 59863
# Downloaded and processed image 55131 of 59863
# Downloaded and processed image 55132 of 59863
# Downloaded and processed image 55133 of 59863
# Downloaded and processed image 55134 of 59863
# Downloaded and processed image 55135 of 59863
# Downloaded and processed image 55136 of 59863
# Downloaded and processed image 55137 of 59863
# Downloaded and processed image 55138 of 59863
# Downloaded and processed image 55139 of 59863
# Downloaded and processed image 55140 of 59863
# Downloaded and processed image 55141 of 59863
# Downloaded and processed image 55142 of 59863
# Downloaded and processed image 55143 of 59863
# Downloaded and processed image 55144 of 59863
# Downloaded and processed image 55145 of 59863
# Downloaded and processed image 55146 of 59863
# Downloaded and processed image 55147 of 59863
# Downloaded and processed image 55148 of 59863
# Downloaded and processed image 55149 of 59863
# Downloaded and processed image 55150 of 59863
# Downloaded and processed image 55151 of 59863
# Downloaded and processed image 55152 of 59863
# Downloaded and processed image 55153 of 59863
# Downloaded and processed image 55154 of 59863
# Downloaded and processed image 55155 of 59863
# Downloaded and processed image 55156 of 59863
# Downloaded and processed image 55157 of 59863
# Downloaded and processed image 55158 of 59863
# Downloaded and processed image 55159 of 59863
# Downloaded and processed image 55160 of 59863
# Downloaded and processed image 55161 of 59863
# Downloaded and processed image 55162 of 59863
# Downloaded and processed image 55163 of 59863
# Downloaded and processed image 55164 of 59863
# Downloaded and processed image 55165 of 59863
# Downloaded and processed image 55166 of 59863
# Downloaded and processed image 55167 of 59863
# Downloaded and processed image 55168 of 59863
# Downloaded and processed image 55169 of 59863
# Downloaded and processed image 55170 of 59863
# Downloaded and processed image 55171 of 59863
# Downloaded and processed image 55172 of 59863
# Downloaded and processed image 55173 of 59863
# Downloaded and processed image 55174 of 59863
# Downloaded and processed image 55175 of 59863
# Downloaded and processed image 55176 of 59863
# Downloaded and processed image 55177 of 59863
# Downloaded and processed image 55178 of 59863
# Downloaded and processed image 55179 of 59863
# Downloaded and processed image 55180 of 59863
# Downloaded and processed image 55181 of 59863
# Downloaded and processed image 55182 of 59863
# Downloaded and processed image 55183 of 59863
# Downloaded and processed image 55184 of 59863
# Downloaded and processed image 55185 of 59863
# Downloaded and processed image 55186 of 59863
# Downloaded and processed image 55187 of 59863
# Downloaded and processed image 55188 of 59863
# Downloaded and processed image 55189 of 59863
# Downloaded and processed image 55190 of 59863
# Downloaded and processed image 55191 of 59863
# Downloaded and processed image 55192 of 59863
# Downloaded and processed image 55193 of 59863
# Downloaded and processed image 55194 of 59863
# Downloaded and processed image 55195 of 59863
# Downloaded and processed image 55196 of 59863
# Downloaded and processed image 55197 of 59863
# Downloaded and processed image 55198 of 59863
# Downloaded and processed image 55199 of 59863
# Downloaded and processed image 55200 of 59863
# Downloaded and processed image 55201 of 59863
# Downloaded and processed image 55202 of 59863
# Downloaded and processed image 55203 of 59863
# Downloaded and processed image 55204 of 59863
# Downloaded and processed image 55205 of 59863
# Downloaded and processed image 55206 of 59863
# Downloaded and processed image 55207 of 59863
# Downloaded and processed image 55208 of 59863
# Downloaded and processed image 55209 of 59863
# Downloaded and processed image 55210 of 59863
# Downloaded and processed image 55211 of 59863
# Downloaded and processed image 55212 of 59863
# Downloaded and processed image 55213 of 59863
# Downloaded and processed image 55214 of 59863
# Downloaded and processed image 55215 of 59863
# Downloaded and processed image 55216 of 59863
# Downloaded and processed image 55217 of 59863
# Downloaded and processed image 55218 of 59863
# Downloaded and processed image 55219 of 59863
# Downloaded and processed image 55220 of 59863
# Downloaded and processed image 55221 of 59863
# Downloaded and processed image 55222 of 59863
# Downloaded and processed image 55223 of 59863
# Downloaded and processed image 55224 of 59863
# Downloaded and processed image 55225 of 59863
# Downloaded and processed image 55226 of 59863
# Downloaded and processed image 55227 of 59863
# Downloaded and processed image 55228 of 59863
# Downloaded and processed image 55229 of 59863
# Downloaded and processed image 55230 of 59863
# Downloaded and processed image 55231 of 59863
# Downloaded and processed image 55232 of 59863
# Downloaded and processed image 55233 of 59863
# Downloaded and processed image 55234 of 59863
# Downloaded and processed image 55235 of 59863
# Downloaded and processed image 55236 of 59863
# Downloaded and processed image 55237 of 59863
# Downloaded and processed image 55238 of 59863
# Downloaded and processed image 55239 of 59863
# Downloaded and processed image 55240 of 59863
# Downloaded and processed image 55241 of 59863
# Downloaded and processed image 55242 of 59863
# Downloaded and processed image 55243 of 59863
# Downloaded and processed image 55244 of 59863
# Downloaded and processed image 55245 of 59863
# Downloaded and processed image 55246 of 59863
# Downloaded and processed image 55247 of 59863
# Downloaded and processed image 55248 of 59863
# Downloaded and processed image 55249 of 59863
# Downloaded and processed image 55250 of 59863
# Downloaded and processed image 55251 of 59863
# Downloaded and processed image 55252 of 59863
# Downloaded and processed image 55253 of 59863
# Downloaded and processed image 55254 of 59863
# Downloaded and processed image 55255 of 59863
# Downloaded and processed image 55256 of 59863
# Downloaded and processed image 55257 of 59863
# Downloaded and processed image 55258 of 59863
# Downloaded and processed image 55259 of 59863
# Downloaded and processed image 55260 of 59863
# Downloaded and processed image 55261 of 59863
# Downloaded and processed image 55262 of 59863
# Downloaded and processed image 55263 of 59863
# Downloaded and processed image 55264 of 59863
# Downloaded and processed image 55265 of 59863
# Downloaded and processed image 55266 of 59863
# Downloaded and processed image 55267 of 59863
# Downloaded and processed image 55268 of 59863
# Downloaded and processed image 55269 of 59863
# Downloaded and processed image 55270 of 59863
# Downloaded and processed image 55271 of 59863
# Downloaded and processed image 55272 of 59863
# Downloaded and processed image 55273 of 59863
# Downloaded and processed image 55274 of 59863
# Downloaded and processed image 55275 of 59863
# Downloaded and processed image 55276 of 59863
# Downloaded and processed image 55277 of 59863
# Downloaded and processed image 55278 of 59863
# Downloaded and processed image 55279 of 59863
# Downloaded and processed image 55280 of 59863
# Downloaded and processed image 55281 of 59863
# Downloaded and processed image 55282 of 59863
# Downloaded and processed image 55283 of 59863
# Downloaded and processed image 55284 of 59863
# Downloaded and processed image 55285 of 59863
# Downloaded and processed image 55286 of 59863
# Downloaded and processed image 55287 of 59863
# Downloaded and processed image 55288 of 59863
# Downloaded and processed image 55289 of 59863
# Downloaded and processed image 55290 of 59863
# Downloaded and processed image 55291 of 59863
# Downloaded and processed image 55292 of 59863
# Downloaded and processed image 55293 of 59863
# Downloaded and processed image 55294 of 59863
# Downloaded and processed image 55295 of 59863
# Downloaded and processed image 55296 of 59863
# Downloaded and processed image 55297 of 59863
# Downloaded and processed image 55298 of 59863
# Downloaded and processed image 55299 of 59863
# Downloaded and processed image 55300 of 59863
# Downloaded and processed image 55301 of 59863
# Downloaded and processed image 55302 of 59863
# Downloaded and processed image 55303 of 59863
# Downloaded and processed image 55304 of 59863
# Downloaded and processed image 55305 of 59863
# Downloaded and processed image 55306 of 59863
# Downloaded and processed image 55307 of 59863
# Downloaded and processed image 55308 of 59863
# Downloaded and processed image 55309 of 59863
# Downloaded and processed image 55310 of 59863
# Downloaded and processed image 55311 of 59863
# Downloaded and processed image 55312 of 59863
# Downloaded and processed image 55313 of 59863
# Downloaded and processed image 55314 of 59863
# Downloaded and processed image 55315 of 59863
# Downloaded and processed image 55316 of 59863
# Downloaded and processed image 55317 of 59863
# Downloaded and processed image 55318 of 59863
# Downloaded and processed image 55319 of 59863
# Downloaded and processed image 55320 of 59863
# Downloaded and processed image 55321 of 59863
# Downloaded and processed image 55322 of 59863
# Downloaded and processed image 55323 of 59863
# Downloaded and processed image 55324 of 59863
# Downloaded and processed image 55325 of 59863
# Downloaded and processed image 55326 of 59863
# Downloaded and processed image 55327 of 59863
# Downloaded and processed image 55328 of 59863
# Downloaded and processed image 55329 of 59863
# Downloaded and processed image 55330 of 59863
# Downloaded and processed image 55331 of 59863
# Downloaded and processed image 55332 of 59863
# Downloaded and processed image 55333 of 59863
# Downloaded and processed image 55334 of 59863
# Downloaded and processed image 55335 of 59863
# Downloaded and processed image 55336 of 59863
# Downloaded and processed image 55337 of 59863
# Downloaded and processed image 55338 of 59863
# Downloaded and processed image 55339 of 59863
# Downloaded and processed image 55340 of 59863
# Downloaded and processed image 55341 of 59863
# Downloaded and processed image 55342 of 59863
# Downloaded and processed image 55343 of 59863
# Downloaded and processed image 55344 of 59863
# Downloaded and processed image 55345 of 59863
# Downloaded and processed image 55346 of 59863
# Downloaded and processed image 55347 of 59863
# Downloaded and processed image 55348 of 59863
# Downloaded and processed image 55349 of 59863
# Downloaded and processed image 55350 of 59863
# Downloaded and processed image 55351 of 59863
# Downloaded and processed image 55352 of 59863
# Downloaded and processed image 55353 of 59863
# Downloaded and processed image 55354 of 59863
# Downloaded and processed image 55355 of 59863
# Downloaded and processed image 55356 of 59863
# Downloaded and processed image 55357 of 59863
# Downloaded and processed image 55358 of 59863
# Downloaded and processed image 55359 of 59863
# Downloaded and processed image 55360 of 59863
# Downloaded and processed image 55361 of 59863
# Downloaded and processed image 55362 of 59863
# Downloaded and processed image 55363 of 59863
# Downloaded and processed image 55364 of 59863
# Downloaded and processed image 55365 of 59863
# Downloaded and processed image 55366 of 59863
# Downloaded and processed image 55367 of 59863
# Downloaded and processed image 55368 of 59863
# Downloaded and processed image 55369 of 59863
# Downloaded and processed image 55370 of 59863
# Downloaded and processed image 55371 of 59863
# Downloaded and processed image 55372 of 59863
# Downloaded and processed image 55373 of 59863
# Downloaded and processed image 55374 of 59863
# Downloaded and processed image 55375 of 59863
# Downloaded and processed image 55376 of 59863
# Downloaded and processed image 55377 of 59863
# Downloaded and processed image 55378 of 59863
# Downloaded and processed image 55379 of 59863
# Downloaded and processed image 55380 of 59863
# Downloaded and processed image 55381 of 59863
# Downloaded and processed image 55382 of 59863
# Downloaded and processed image 55383 of 59863
# Downloaded and processed image 55384 of 59863
# Downloaded and processed image 55385 of 59863
# Downloaded and processed image 55386 of 59863
# Downloaded and processed image 55387 of 59863
# Downloaded and processed image 55388 of 59863
# Downloaded and processed image 55389 of 59863
# Downloaded and processed image 55390 of 59863
# Downloaded and processed image 55391 of 59863
# Downloaded and processed image 55392 of 59863
# Downloaded and processed image 55393 of 59863
# Downloaded and processed image 55394 of 59863
# Downloaded and processed image 55395 of 59863
# Downloaded and processed image 55396 of 59863
# Downloaded and processed image 55397 of 59863
# Downloaded and processed image 55398 of 59863
# Downloaded and processed image 55399 of 59863
# Downloaded and processed image 55400 of 59863
# Downloaded and processed image 55401 of 59863
# Downloaded and processed image 55402 of 59863
# Downloaded and processed image 55403 of 59863
# Downloaded and processed image 55404 of 59863
# Downloaded and processed image 55405 of 59863
# Downloaded and processed image 55406 of 59863
# Downloaded and processed image 55407 of 59863
# Downloaded and processed image 55408 of 59863
# Downloaded and processed image 55409 of 59863
# Downloaded and processed image 55410 of 59863
# Downloaded and processed image 55411 of 59863
# Downloaded and processed image 55412 of 59863
# Downloaded and processed image 55413 of 59863
# Downloaded and processed image 55414 of 59863
# Downloaded and processed image 55415 of 59863
# Downloaded and processed image 55416 of 59863
# Downloaded and processed image 55417 of 59863
# Downloaded and processed image 55418 of 59863
# Downloaded and processed image 55419 of 59863
# Downloaded and processed image 55420 of 59863
# Downloaded and processed image 55421 of 59863
# Downloaded and processed image 55422 of 59863
# Downloaded and processed image 55423 of 59863
# Downloaded and processed image 55424 of 59863
# Downloaded and processed image 55425 of 59863
# Downloaded and processed image 55426 of 59863
# Downloaded and processed image 55427 of 59863
# Downloaded and processed image 55428 of 59863
# Downloaded and processed image 55429 of 59863
# Downloaded and processed image 55430 of 59863
# Downloaded and processed image 55431 of 59863
# Downloaded and processed image 55432 of 59863
# Downloaded and processed image 55433 of 59863
# Downloaded and processed image 55434 of 59863
# Downloaded and processed image 55435 of 59863
# Downloaded and processed image 55436 of 59863
# Downloaded and processed image 55437 of 59863
# Downloaded and processed image 55438 of 59863
# Downloaded and processed image 55439 of 59863
# Downloaded and processed image 55440 of 59863
# Downloaded and processed image 55441 of 59863
# Downloaded and processed image 55442 of 59863
# Downloaded and processed image 55443 of 59863
# Downloaded and processed image 55444 of 59863
# Downloaded and processed image 55445 of 59863
# Downloaded and processed image 55446 of 59863
# Downloaded and processed image 55447 of 59863
# Downloaded and processed image 55448 of 59863
# Downloaded and processed image 55449 of 59863
# Downloaded and processed image 55450 of 59863
# Downloaded and processed image 55451 of 59863
# Downloaded and processed image 55452 of 59863
# Downloaded and processed image 55453 of 59863
# Downloaded and processed image 55454 of 59863
# Downloaded and processed image 55455 of 59863
# Downloaded and processed image 55456 of 59863
# Downloaded and processed image 55457 of 59863
# Downloaded and processed image 55458 of 59863
# Downloaded and processed image 55459 of 59863
# Downloaded and processed image 55460 of 59863
# Downloaded and processed image 55461 of 59863
# Downloaded and processed image 55462 of 59863
# Downloaded and processed image 55463 of 59863
# Downloaded and processed image 55464 of 59863
# Downloaded and processed image 55465 of 59863
# Downloaded and processed image 55466 of 59863
# Downloaded and processed image 55467 of 59863
# Downloaded and processed image 55468 of 59863
# Downloaded and processed image 55469 of 59863
# Downloaded and processed image 55470 of 59863
# Downloaded and processed image 55471 of 59863
# Downloaded and processed image 55472 of 59863
# Downloaded and processed image 55473 of 59863
# Downloaded and processed image 55474 of 59863
# Downloaded and processed image 55475 of 59863
# Downloaded and processed image 55476 of 59863
# Downloaded and processed image 55477 of 59863
# Downloaded and processed image 55478 of 59863
# Downloaded and processed image 55479 of 59863
# Downloaded and processed image 55480 of 59863
# Downloaded and processed image 55481 of 59863
# Downloaded and processed image 55482 of 59863
# Downloaded and processed image 55483 of 59863
# Downloaded and processed image 55484 of 59863
# Downloaded and processed image 55485 of 59863
# Downloaded and processed image 55486 of 59863
# Downloaded and processed image 55487 of 59863
# Downloaded and processed image 55488 of 59863
# Downloaded and processed image 55489 of 59863
# Downloaded and processed image 55490 of 59863
# Downloaded and processed image 55491 of 59863
# Downloaded and processed image 55492 of 59863
# Downloaded and processed image 55493 of 59863
# Downloaded and processed image 55494 of 59863
# Downloaded and processed image 55495 of 59863
# Downloaded and processed image 55496 of 59863
# Downloaded and processed image 55497 of 59863
# Downloaded and processed image 55498 of 59863
# Downloaded and processed image 55499 of 59863
# Downloaded and processed image 55500 of 59863
# Downloaded and processed image 55501 of 59863
# Downloaded and processed image 55502 of 59863
# Downloaded and processed image 55503 of 59863
# Downloaded and processed image 55504 of 59863
# Downloaded and processed image 55505 of 59863
# Downloaded and processed image 55506 of 59863
# Downloaded and processed image 55507 of 59863
# Downloaded and processed image 55508 of 59863
# Downloaded and processed image 55509 of 59863
# Downloaded and processed image 55510 of 59863
# Downloaded and processed image 55511 of 59863
# Downloaded and processed image 55512 of 59863
# Downloaded and processed image 55513 of 59863
# Downloaded and processed image 55514 of 59863
# Downloaded and processed image 55515 of 59863
# Downloaded and processed image 55516 of 59863
# Downloaded and processed image 55517 of 59863
# Downloaded and processed image 55518 of 59863
# Downloaded and processed image 55519 of 59863
# Downloaded and processed image 55520 of 59863
# Downloaded and processed image 55521 of 59863
# Downloaded and processed image 55522 of 59863
# Downloaded and processed image 55523 of 59863
# Downloaded and processed image 55524 of 59863
# Downloaded and processed image 55525 of 59863
# Downloaded and processed image 55526 of 59863
# Downloaded and processed image 55527 of 59863
# Downloaded and processed image 55528 of 59863
# Downloaded and processed image 55529 of 59863
# Downloaded and processed image 55530 of 59863
# Downloaded and processed image 55531 of 59863
# Downloaded and processed image 55532 of 59863
# Downloaded and processed image 55533 of 59863
# Downloaded and processed image 55534 of 59863
# Downloaded and processed image 55535 of 59863
# Downloaded and processed image 55536 of 59863
# Downloaded and processed image 55537 of 59863
# Downloaded and processed image 55538 of 59863
# Downloaded and processed image 55539 of 59863
# Downloaded and processed image 55540 of 59863
# Downloaded and processed image 55541 of 59863
# Downloaded and processed image 55542 of 59863
# Downloaded and processed image 55543 of 59863
# Downloaded and processed image 55544 of 59863
# Downloaded and processed image 55545 of 59863
# Downloaded and processed image 55546 of 59863
# Downloaded and processed image 55547 of 59863
# Downloaded and processed image 55548 of 59863
# Downloaded and processed image 55549 of 59863
# Downloaded and processed image 55550 of 59863
# Downloaded and processed image 55551 of 59863
# Downloaded and processed image 55552 of 59863
# Downloaded and processed image 55553 of 59863
# Downloaded and processed image 55554 of 59863
# Downloaded and processed image 55555 of 59863
# Downloaded and processed image 55556 of 59863
# Downloaded and processed image 55557 of 59863
# Downloaded and processed image 55558 of 59863
# Downloaded and processed image 55559 of 59863
# Downloaded and processed image 55560 of 59863
# Downloaded and processed image 55561 of 59863
# Downloaded and processed image 55562 of 59863
# Downloaded and processed image 55563 of 59863
# Downloaded and processed image 55564 of 59863
# Downloaded and processed image 55565 of 59863
# Downloaded and processed image 55566 of 59863
# Downloaded and processed image 55567 of 59863
# Downloaded and processed image 55568 of 59863
# Downloaded and processed image 55569 of 59863
# Downloaded and processed image 55570 of 59863
# Downloaded and processed image 55571 of 59863
# Downloaded and processed image 55572 of 59863
# Downloaded and processed image 55573 of 59863
# Downloaded and processed image 55574 of 59863
# Downloaded and processed image 55575 of 59863
# Downloaded and processed image 55576 of 59863
# Downloaded and processed image 55577 of 59863
# Downloaded and processed image 55578 of 59863
# Downloaded and processed image 55579 of 59863
# Downloaded and processed image 55580 of 59863
# Downloaded and processed image 55581 of 59863
# Downloaded and processed image 55582 of 59863
# Downloaded and processed image 55583 of 59863
# Downloaded and processed image 55584 of 59863
# Downloaded and processed image 55585 of 59863
# Downloaded and processed image 55586 of 59863
# Downloaded and processed image 55587 of 59863
# Downloaded and processed image 55588 of 59863
# Downloaded and processed image 55589 of 59863
# Downloaded and processed image 55590 of 59863
# Downloaded and processed image 55591 of 59863
# Downloaded and processed image 55592 of 59863
# Downloaded and processed image 55593 of 59863
# Downloaded and processed image 55594 of 59863
# Downloaded and processed image 55595 of 59863
# Downloaded and processed image 55596 of 59863
# Downloaded and processed image 55597 of 59863
# Downloaded and processed image 55598 of 59863
# Downloaded and processed image 55599 of 59863
# Downloaded and processed image 55600 of 59863
# Downloaded and processed image 55601 of 59863
# Downloaded and processed image 55602 of 59863
# Downloaded and processed image 55603 of 59863
# Downloaded and processed image 55604 of 59863
# Downloaded and processed image 55605 of 59863
# Downloaded and processed image 55606 of 59863
# Downloaded and processed image 55607 of 59863
# Downloaded and processed image 55608 of 59863
# Downloaded and processed image 55609 of 59863
# Downloaded and processed image 55610 of 59863
# Downloaded and processed image 55611 of 59863
# Downloaded and processed image 55612 of 59863
# Downloaded and processed image 55613 of 59863
# Downloaded and processed image 55614 of 59863
# Downloaded and processed image 55615 of 59863
# Downloaded and processed image 55616 of 59863
# Downloaded and processed image 55617 of 59863
# Downloaded and processed image 55618 of 59863
# Downloaded and processed image 55619 of 59863
# Downloaded and processed image 55620 of 59863
# Downloaded and processed image 55621 of 59863
# Downloaded and processed image 55622 of 59863
# Downloaded and processed image 55623 of 59863
# Downloaded and processed image 55624 of 59863
# Downloaded and processed image 55625 of 59863
# Downloaded and processed image 55626 of 59863
# Downloaded and processed image 55627 of 59863
# Downloaded and processed image 55628 of 59863
# Downloaded and processed image 55629 of 59863
# Downloaded and processed image 55630 of 59863
# Downloaded and processed image 55631 of 59863
# Downloaded and processed image 55632 of 59863
# Downloaded and processed image 55633 of 59863
# Downloaded and processed image 55634 of 59863
# Downloaded and processed image 55635 of 59863
# Downloaded and processed image 55636 of 59863
# Downloaded and processed image 55637 of 59863
# Downloaded and processed image 55638 of 59863
# Downloaded and processed image 55639 of 59863
# Downloaded and processed image 55640 of 59863
# Downloaded and processed image 55641 of 59863
# Downloaded and processed image 55642 of 59863
# Downloaded and processed image 55643 of 59863
# Downloaded and processed image 55644 of 59863
# Downloaded and processed image 55645 of 59863
# Downloaded and processed image 55646 of 59863
# Downloaded and processed image 55647 of 59863
# Downloaded and processed image 55648 of 59863
# Downloaded and processed image 55649 of 59863
# Downloaded and processed image 55650 of 59863
# Downloaded and processed image 55651 of 59863
# Downloaded and processed image 55652 of 59863
# Downloaded and processed image 55653 of 59863
# Downloaded and processed image 55654 of 59863
# Downloaded and processed image 55655 of 59863
# Downloaded and processed image 55656 of 59863
# Downloaded and processed image 55657 of 59863
# Downloaded and processed image 55658 of 59863
# Downloaded and processed image 55659 of 59863
# Downloaded and processed image 55660 of 59863
# Downloaded and processed image 55661 of 59863
# Downloaded and processed image 55662 of 59863
# Downloaded and processed image 55663 of 59863
# Downloaded and processed image 55664 of 59863
# Downloaded and processed image 55665 of 59863
# Downloaded and processed image 55666 of 59863
# Downloaded and processed image 55667 of 59863
# Downloaded and processed image 55668 of 59863
# Downloaded and processed image 55669 of 59863
# Downloaded and processed image 55670 of 59863
# Downloaded and processed image 55671 of 59863
# Downloaded and processed image 55672 of 59863
# Downloaded and processed image 55673 of 59863
# Downloaded and processed image 55674 of 59863
# Downloaded and processed image 55675 of 59863
# Downloaded and processed image 55676 of 59863
# Downloaded and processed image 55677 of 59863
# Downloaded and processed image 55678 of 59863
# Downloaded and processed image 55679 of 59863
# Downloaded and processed image 55680 of 59863
# Downloaded and processed image 55681 of 59863
# Downloaded and processed image 55682 of 59863
# Downloaded and processed image 55683 of 59863
# Downloaded and processed image 55684 of 59863
# Downloaded and processed image 55685 of 59863
# Downloaded and processed image 55686 of 59863
# Downloaded and processed image 55687 of 59863
# Downloaded and processed image 55688 of 59863
# Downloaded and processed image 55689 of 59863
# Downloaded and processed image 55690 of 59863
# Downloaded and processed image 55691 of 59863
# Downloaded and processed image 55692 of 59863
# Downloaded and processed image 55693 of 59863
# Downloaded and processed image 55694 of 59863
# Downloaded and processed image 55695 of 59863
# Downloaded and processed image 55696 of 59863
# Downloaded and processed image 55697 of 59863
# Downloaded and processed image 55698 of 59863
# Downloaded and processed image 55699 of 59863
# Downloaded and processed image 55700 of 59863
# Downloaded and processed image 55701 of 59863
# Downloaded and processed image 55702 of 59863
# Downloaded and processed image 55703 of 59863
# Downloaded and processed image 55704 of 59863
# Downloaded and processed image 55705 of 59863
# Downloaded and processed image 55706 of 59863
# Downloaded and processed image 55707 of 59863
# Downloaded and processed image 55708 of 59863
# Downloaded and processed image 55709 of 59863
# Downloaded and processed image 55710 of 59863
# Downloaded and processed image 55711 of 59863
# Downloaded and processed image 55712 of 59863
# Downloaded and processed image 55713 of 59863
# Downloaded and processed image 55714 of 59863
# Downloaded and processed image 55715 of 59863
# Downloaded and processed image 55716 of 59863
# Downloaded and processed image 55717 of 59863
# Downloaded and processed image 55718 of 59863
# Downloaded and processed image 55719 of 59863
# Downloaded and processed image 55720 of 59863
# Downloaded and processed image 55721 of 59863
# Downloaded and processed image 55722 of 59863
# Downloaded and processed image 55723 of 59863
# Downloaded and processed image 55724 of 59863
# Downloaded and processed image 55725 of 59863
# Downloaded and processed image 55726 of 59863
# Downloaded and processed image 55727 of 59863
# Downloaded and processed image 55728 of 59863
# Downloaded and processed image 55729 of 59863
# Downloaded and processed image 55730 of 59863
# Downloaded and processed image 55731 of 59863
# Downloaded and processed image 55732 of 59863
# Downloaded and processed image 55733 of 59863
# Downloaded and processed image 55734 of 59863
# Downloaded and processed image 55735 of 59863
# Downloaded and processed image 55736 of 59863
# Downloaded and processed image 55737 of 59863
# Downloaded and processed image 55738 of 59863
# Downloaded and processed image 55739 of 59863
# Downloaded and processed image 55740 of 59863
# Downloaded and processed image 55741 of 59863
# Downloaded and processed image 55742 of 59863
# Downloaded and processed image 55743 of 59863
# Downloaded and processed image 55744 of 59863
# Downloaded and processed image 55745 of 59863
# Downloaded and processed image 55746 of 59863
# Downloaded and processed image 55747 of 59863
# Downloaded and processed image 55748 of 59863
# Downloaded and processed image 55749 of 59863
# Downloaded and processed image 55750 of 59863
# Downloaded and processed image 55751 of 59863
# Downloaded and processed image 55752 of 59863
# Downloaded and processed image 55753 of 59863
# Downloaded and processed image 55754 of 59863
# Downloaded and processed image 55755 of 59863
# Downloaded and processed image 55756 of 59863
# Downloaded and processed image 55757 of 59863
# Downloaded and processed image 55758 of 59863
# Downloaded and processed image 55759 of 59863
# Downloaded and processed image 55760 of 59863
# Downloaded and processed image 55761 of 59863
# Downloaded and processed image 55762 of 59863
# Downloaded and processed image 55763 of 59863
# Downloaded and processed image 55764 of 59863
# Downloaded and processed image 55765 of 59863
# Downloaded and processed image 55766 of 59863
# Downloaded and processed image 55767 of 59863
# Downloaded and processed image 55768 of 59863
# Downloaded and processed image 55769 of 59863
# Downloaded and processed image 55770 of 59863
# Downloaded and processed image 55771 of 59863
# Downloaded and processed image 55772 of 59863
# Downloaded and processed image 55773 of 59863
# Downloaded and processed image 55774 of 59863
# Downloaded and processed image 55775 of 59863
# Downloaded and processed image 55776 of 59863
# Downloaded and processed image 55777 of 59863
# Downloaded and processed image 55778 of 59863
# Downloaded and processed image 55779 of 59863
# Downloaded and processed image 55780 of 59863
# Downloaded and processed image 55781 of 59863
# Downloaded and processed image 55782 of 59863
# Downloaded and processed image 55783 of 59863
# Downloaded and processed image 55784 of 59863
# Downloaded and processed image 55785 of 59863
# Downloaded and processed image 55786 of 59863
# Downloaded and processed image 55787 of 59863
# Downloaded and processed image 55788 of 59863
# Downloaded and processed image 55789 of 59863
# Downloaded and processed image 55790 of 59863
# Downloaded and processed image 55791 of 59863
# Downloaded and processed image 55792 of 59863
# Downloaded and processed image 55793 of 59863
# Downloaded and processed image 55794 of 59863
# Downloaded and processed image 55795 of 59863
# Downloaded and processed image 55796 of 59863
# Downloaded and processed image 55797 of 59863
# Downloaded and processed image 55798 of 59863
# Downloaded and processed image 55799 of 59863
# Downloaded and processed image 55800 of 59863
# Downloaded and processed image 55801 of 59863
# Downloaded and processed image 55802 of 59863
# Downloaded and processed image 55803 of 59863
# Downloaded and processed image 55804 of 59863
# Downloaded and processed image 55805 of 59863
# Downloaded and processed image 55806 of 59863
# Downloaded and processed image 55807 of 59863
# Downloaded and processed image 55808 of 59863
# Downloaded and processed image 55809 of 59863
# Downloaded and processed image 55810 of 59863
# Downloaded and processed image 55811 of 59863
# Downloaded and processed image 55812 of 59863
# Downloaded and processed image 55813 of 59863
# Downloaded and processed image 55814 of 59863
# Downloaded and processed image 55815 of 59863
# Downloaded and processed image 55816 of 59863
# Downloaded and processed image 55817 of 59863
# Downloaded and processed image 55818 of 59863
# Downloaded and processed image 55819 of 59863
# Downloaded and processed image 55820 of 59863
# Downloaded and processed image 55821 of 59863
# Downloaded and processed image 55822 of 59863
# Downloaded and processed image 55823 of 59863
# Downloaded and processed image 55824 of 59863
# Downloaded and processed image 55825 of 59863
# Downloaded and processed image 55826 of 59863
# Downloaded and processed image 55827 of 59863
# Downloaded and processed image 55828 of 59863
# Downloaded and processed image 55829 of 59863
# Downloaded and processed image 55830 of 59863
# Downloaded and processed image 55831 of 59863
# Downloaded and processed image 55832 of 59863
# Downloaded and processed image 55833 of 59863
# Downloaded and processed image 55834 of 59863
# Downloaded and processed image 55835 of 59863
# Downloaded and processed image 55836 of 59863
# Downloaded and processed image 55837 of 59863
# Downloaded and processed image 55838 of 59863
# Downloaded and processed image 55839 of 59863
# Downloaded and processed image 55840 of 59863
# Downloaded and processed image 55841 of 59863
# Downloaded and processed image 55842 of 59863
# Downloaded and processed image 55843 of 59863
# Downloaded and processed image 55844 of 59863
# Downloaded and processed image 55845 of 59863
# Downloaded and processed image 55846 of 59863
# Downloaded and processed image 55847 of 59863
# Downloaded and processed image 55848 of 59863
# Downloaded and processed image 55849 of 59863
# Downloaded and processed image 55850 of 59863
# Downloaded and processed image 55851 of 59863
# Downloaded and processed image 55852 of 59863
# Downloaded and processed image 55853 of 59863
# Downloaded and processed image 55854 of 59863
# Downloaded and processed image 55855 of 59863
# Downloaded and processed image 55856 of 59863
# Downloaded and processed image 55857 of 59863
# Downloaded and processed image 55858 of 59863
# Downloaded and processed image 55859 of 59863
# Downloaded and processed image 55860 of 59863
# Downloaded and processed image 55861 of 59863
# Downloaded and processed image 55862 of 59863
# Downloaded and processed image 55863 of 59863
# Downloaded and processed image 55864 of 59863
# Downloaded and processed image 55865 of 59863
# Downloaded and processed image 55866 of 59863
# Downloaded and processed image 55867 of 59863
# Downloaded and processed image 55868 of 59863
# Downloaded and processed image 55869 of 59863
# Downloaded and processed image 55870 of 59863
# Downloaded and processed image 55871 of 59863
# Downloaded and processed image 55872 of 59863
# Downloaded and processed image 55873 of 59863
# Downloaded and processed image 55874 of 59863
# Downloaded and processed image 55875 of 59863
# Downloaded and processed image 55876 of 59863
# Downloaded and processed image 55877 of 59863
# Downloaded and processed image 55878 of 59863
# Downloaded and processed image 55879 of 59863
# Downloaded and processed image 55880 of 59863
# Downloaded and processed image 55881 of 59863
# Downloaded and processed image 55882 of 59863
# Downloaded and processed image 55883 of 59863
# Downloaded and processed image 55884 of 59863
# Downloaded and processed image 55885 of 59863
# Downloaded and processed image 55886 of 59863
# Downloaded and processed image 55887 of 59863
# Downloaded and processed image 55888 of 59863
# Downloaded and processed image 55889 of 59863
# Downloaded and processed image 55890 of 59863
# Downloaded and processed image 55891 of 59863
# Downloaded and processed image 55892 of 59863
# Downloaded and processed image 55893 of 59863
# Downloaded and processed image 55894 of 59863
# Downloaded and processed image 55895 of 59863
# Downloaded and processed image 55896 of 59863
# Downloaded and processed image 55897 of 59863
# Downloaded and processed image 55898 of 59863
# Downloaded and processed image 55899 of 59863
# Downloaded and processed image 55900 of 59863
# Downloaded and processed image 55901 of 59863
# Downloaded and processed image 55902 of 59863
# Downloaded and processed image 55903 of 59863
# Downloaded and processed image 55904 of 59863
# Downloaded and processed image 55905 of 59863
# Downloaded and processed image 55906 of 59863
# ...
# Downloaded and processed image 59518 of 59863
# Downloaded and processed image 59519 of 59863
# Downloaded and processed image 59520 of 59863
# Downloaded and processed image 59521 of 59863
# Downloaded and processed image 59522 of 59863
# Downloaded and processed image 59523 of 59863
# Downloaded and processed image 59524 of 59863
# Downloaded and processed image 59525 of 59863
# Downloaded and processed image 59526 of 59863
# Downloaded and processed image 59527 of 59863
# Downloaded and processed image 59528 of 59863
# Downloaded and processed image 59529 of 59863
# Downloaded and processed image 59530 of 59863
# Downloaded and processed image 59531 of 59863
# Downloaded and processed image 59532 of 59863
# Downloaded and processed image 59533 of 59863
# Downloaded and processed image 59534 of 59863
# Downloaded and processed image 59535 of 59863
# Downloaded and processed image 59536 of 59863
# Downloaded and processed image 59537 of 59863
# Downloaded and processed image 59538 of 59863
# Downloaded and processed image 59539 of 59863
# Downloaded and processed image 59540 of 59863
# Downloaded and processed image 59541 of 59863
# Downloaded and processed image 59542 of 59863
# Downloaded and processed image 59543 of 59863
# Downloaded and processed image 59544 of 59863
# Downloaded and processed image 59545 of 59863
# Downloaded and processed image 59546 of 59863
# Downloaded and processed image 59547 of 59863
# Downloaded and processed image 59548 of 59863
# Downloaded and processed image 59549 of 59863
# Downloaded and processed image 59550 of 59863
# Downloaded and processed image 59551 of 59863
# Downloaded and processed image 59552 of 59863
# Downloaded and processed image 59553 of 59863
# Downloaded and processed image 59554 of 59863
# Downloaded and processed image 59555 of 59863
# Downloaded and processed image 59556 of 59863
# Downloaded and processed image 59557 of 59863
# Downloaded and processed image 59558 of 59863
# Downloaded and processed image 59559 of 59863
# Downloaded and processed image 59560 of 59863
# Downloaded and processed image 59561 of 59863
# Downloaded and processed image 59562 of 59863
# Downloaded and processed image 59563 of 59863
# Downloaded and processed image 59564 of 59863
# Downloaded and processed image 59565 of 59863
# Downloaded and processed image 59566 of 59863
# Downloaded and processed image 59567 of 59863
# Downloaded and processed image 59568 of 59863
# Downloaded and processed image 59569 of 59863
# Downloaded and processed image 59570 of 59863
# Downloaded and processed image 59571 of 59863
# Downloaded and processed image 59572 of 59863
# Downloaded and processed image 59573 of 59863
# Downloaded and processed image 59574 of 59863
# Downloaded and processed image 59575 of 59863
# Downloaded and processed image 59576 of 59863
# Downloaded and processed image 59577 of 59863
# Downloaded and processed image 59578 of 59863
# Downloaded and processed image 59579 of 59863
# Downloaded and processed image 59580 of 59863
# Downloaded and processed image 59581 of 59863
# Downloaded and processed image 59582 of 59863
# Downloaded and processed image 59583 of 59863
# Downloaded and processed image 59584 of 59863
# Downloaded and processed image 59585 of 59863
# Downloaded and processed image 59586 of 59863
# Downloaded and processed image 59587 of 59863
# Downloaded and processed image 59588 of 59863
# Downloaded and processed image 59589 of 59863
# Downloaded and processed image 59590 of 59863
# Downloaded and processed image 59591 of 59863
# Downloaded and processed image 59592 of 59863
# Downloaded and processed image 59593 of 59863
# Downloaded and processed image 59594 of 59863
# Downloaded and processed image 59595 of 59863
# Downloaded and processed image 59596 of 59863
# Downloaded and processed image 59597 of 59863
# Downloaded and processed image 59598 of 59863
# Downloaded and processed image 59599 of 59863
# Downloaded and processed image 59600 of 59863
# Downloaded and processed image 59601 of 59863
# Downloaded and processed image 59602 of 59863
# Downloaded and processed image 59603 of 59863
# Downloaded and processed image 59604 of 59863
# Downloaded and processed image 59605 of 59863
# Downloaded and processed image 59606 of 59863
# Downloaded and processed image 59607 of 59863
# Downloaded and processed image 59608 of 59863
# Downloaded and processed image 59609 of 59863
# Downloaded and processed image 59610 of 59863
# Downloaded and processed image 59611 of 59863
# Downloaded and processed image 59612 of 59863
# Downloaded and processed image 59613 of 59863
# Downloaded and processed image 59614 of 59863
# Downloaded and processed image 59615 of 59863
# Downloaded and processed image 59616 of 59863
# Downloaded and processed image 59617 of 59863
# Downloaded and processed image 59618 of 59863
# Downloaded and processed image 59619 of 59863
# Downloaded and processed image 59620 of 59863
# Downloaded and processed image 59621 of 59863
# Downloaded and processed image 59622 of 59863
# Downloaded and processed image 59623 of 59863
# Downloaded and processed image 59624 of 59863
# Downloaded and processed image 59625 of 59863
# Downloaded and processed image 59626 of 59863
# Downloaded and processed image 59627 of 59863
# Downloaded and processed image 59628 of 59863
# Downloaded and processed image 59629 of 59863
# Downloaded and processed image 59630 of 59863
# Downloaded and processed image 59631 of 59863
# Downloaded and processed image 59632 of 59863
# Downloaded and processed image 59633 of 59863
# Downloaded and processed image 59634 of 59863
# Downloaded and processed image 59635 of 59863
# Downloaded and processed image 59636 of 59863
# Downloaded and processed image 59637 of 59863
# Downloaded and processed image 59638 of 59863
# Downloaded and processed image 59639 of 59863
# Downloaded and processed image 59640 of 59863
# Downloaded and processed image 59641 of 59863
# Downloaded and processed image 59642 of 59863
# Downloaded and processed image 59643 of 59863
# Downloaded and processed image 59644 of 59863
# Downloaded and processed image 59645 of 59863
# Downloaded and processed image 59646 of 59863
# Downloaded and processed image 59647 of 59863
# Downloaded and processed image 59648 of 59863
# Downloaded and processed image 59649 of 59863
# Downloaded and processed image 59650 of 59863
# Downloaded and processed image 59651 of 59863
# Downloaded and processed image 59652 of 59863
# Downloaded and processed image 59653 of 59863
# Downloaded and processed image 59654 of 59863
# Downloaded and processed image 59655 of 59863
# Downloaded and processed image 59656 of 59863
# Downloaded and processed image 59657 of 59863
# Downloaded and processed image 59658 of 59863
# Downloaded and processed image 59659 of 59863
# Downloaded and processed image 59660 of 59863
# Downloaded and processed image 59661 of 59863
# Downloaded and processed image 59662 of 59863
# Downloaded and processed image 59663 of 59863
# Downloaded and processed image 59664 of 59863
# Downloaded and processed image 59665 of 59863
# Downloaded and processed image 59666 of 59863
# Downloaded and processed image 59667 of 59863
# Downloaded and processed image 59668 of 59863
# Downloaded and processed image 59669 of 59863
# Downloaded and processed image 59670 of 59863
# Downloaded and processed image 59671 of 59863
# Downloaded and processed image 59672 of 59863
# Downloaded and processed image 59673 of 59863
# Downloaded and processed image 59674 of 59863
# Downloaded and processed image 59675 of 59863
# Downloaded and processed image 59676 of 59863
# Downloaded and processed image 59677 of 59863
# Downloaded and processed image 59678 of 59863
# Downloaded and processed image 59679 of 59863
# Downloaded and processed image 59680 of 59863
# Downloaded and processed image 59681 of 59863
# Downloaded and processed image 59682 of 59863
# Downloaded and processed image 59683 of 59863
# Downloaded and processed image 59684 of 59863
# Downloaded and processed image 59685 of 59863
# Downloaded and processed image 59686 of 59863
# Downloaded and processed image 59687 of 59863
# Downloaded and processed image 59688 of 59863
# Downloaded and processed image 59689 of 59863
# Downloaded and processed image 59690 of 59863
# Downloaded and processed image 59691 of 59863
# Downloaded and processed image 59692 of 59863
# Downloaded and processed image 59693 of 59863
# Downloaded and processed image 59694 of 59863
# Downloaded and processed image 59695 of 59863
# Downloaded and processed image 59696 of 59863
# Downloaded and processed image 59697 of 59863
# Downloaded and processed image 59698 of 59863
# Downloaded and processed image 59699 of 59863
# Downloaded and processed image 59700 of 59863
# Downloaded and processed image 59701 of 59863
# Downloaded and processed image 59702 of 59863
# Downloaded and processed image 59703 of 59863
# Downloaded and processed image 59704 of 59863
# Downloaded and processed image 59705 of 59863
# Downloaded and processed image 59706 of 59863
# Downloaded and processed image 59707 of 59863
# Downloaded and processed image 59708 of 59863
# Downloaded and processed image 59709 of 59863
# Downloaded and processed image 59710 of 59863
# Downloaded and processed image 59711 of 59863
# Downloaded and processed image 59712 of 59863
# Downloaded and processed image 59713 of 59863
# Downloaded and processed image 59714 of 59863
# Downloaded and processed image 59715 of 59863
# Downloaded and processed image 59716 of 59863
# Downloaded and processed image 59717 of 59863
# Downloaded and processed image 59718 of 59863
# Downloaded and processed image 59719 of 59863
# Downloaded and processed image 59720 of 59863
# Downloaded and processed image 59721 of 59863
# Downloaded and processed image 59722 of 59863
# Downloaded and processed image 59723 of 59863
# Downloaded and processed image 59724 of 59863
# Downloaded and processed image 59725 of 59863
# Downloaded and processed image 59726 of 59863
# Downloaded and processed image 59727 of 59863
# Downloaded and processed image 59728 of 59863
# Downloaded and processed image 59729 of 59863
# Downloaded and processed image 59730 of 59863
# Downloaded and processed image 59731 of 59863
# Downloaded and processed image 59732 of 59863
# Downloaded and processed image 59733 of 59863
# Downloaded and processed image 59734 of 59863
# Downloaded and processed image 59735 of 59863
# Downloaded and processed image 59736 of 59863
# Downloaded and processed image 59737 of 59863
# Downloaded and processed image 59738 of 59863
# Downloaded and processed image 59739 of 59863
# Downloaded and processed image 59740 of 59863
# Downloaded and processed image 59741 of 59863
# Downloaded and processed image 59742 of 59863
# Downloaded and processed image 59743 of 59863
# Downloaded and processed image 59744 of 59863
# Downloaded and processed image 59745 of 59863
# Downloaded and processed image 59746 of 59863
# Downloaded and processed image 59747 of 59863
# Downloaded and processed image 59748 of 59863
# Downloaded and processed image 59749 of 59863
# Downloaded and processed image 59750 of 59863
# Downloaded and processed image 59751 of 59863
# Downloaded and processed image 59752 of 59863
# Downloaded and processed image 59753 of 59863
# Downloaded and processed image 59754 of 59863
# Downloaded and processed image 59755 of 59863
# Downloaded and processed image 59756 of 59863
# Downloaded and processed image 59757 of 59863
# Downloaded and processed image 59758 of 59863
# Downloaded and processed image 59759 of 59863
# Downloaded and processed image 59760 of 59863
# Downloaded and processed image 59761 of 59863
# Downloaded and processed image 59762 of 59863
# Downloaded and processed image 59763 of 59863
# Downloaded and processed image 59764 of 59863
# Downloaded and processed image 59765 of 59863
# Downloaded and processed image 59766 of 59863
# Downloaded and processed image 59767 of 59863
# Downloaded and processed image 59768 of 59863
# Downloaded and processed image 59769 of 59863
# Downloaded and processed image 59770 of 59863
# Downloaded and processed image 59771 of 59863
# Downloaded and processed image 59772 of 59863
# Downloaded and processed image 59773 of 59863
# Downloaded and processed image 59774 of 59863
# Downloaded and processed image 59775 of 59863
# Downloaded and processed image 59776 of 59863
# Downloaded and processed image 59777 of 59863
# Downloaded and processed image 59778 of 59863
# Downloaded and processed image 59779 of 59863
# Downloaded and processed image 59780 of 59863
# Downloaded and processed image 59781 of 59863
# Downloaded and processed image 59782 of 59863
# Downloaded and processed image 59783 of 59863
# Downloaded and processed image 59784 of 59863
# Downloaded and processed image 59785 of 59863
# Downloaded and processed image 59786 of 59863
# Downloaded and processed image 59787 of 59863
# Downloaded and processed image 59788 of 59863
# Downloaded and processed image 59789 of 59863
# Downloaded and processed image 59790 of 59863
# Downloaded and processed image 59791 of 59863
# Downloaded and processed image 59792 of 59863
# Downloaded and processed image 59793 of 59863
# Downloaded and processed image 59794 of 59863
# Downloaded and processed image 59795 of 59863
# Downloaded and processed image 59796 of 59863
# Downloaded and processed image 59797 of 59863
# Downloaded and processed image 59798 of 59863
# Downloaded and processed image 59799 of 59863
# Downloaded and processed image 59800 of 59863
# Downloaded and processed image 59801 of 59863
# Downloaded and processed image 59802 of 59863
# Downloaded and processed image 59803 of 59863
# Downloaded and processed image 59804 of 59863
# Downloaded and processed image 59805 of 59863
# Downloaded and processed image 59806 of 59863
# Downloaded and processed image 59807 of 59863
# Downloaded and processed image 59808 of 59863
# Downloaded and processed image 59809 of 59863
# Downloaded and processed image 59810 of 59863
# Downloaded and processed image 59811 of 59863
# Downloaded and processed image 59812 of 59863
# Downloaded and processed image 59813 of 59863
# Downloaded and processed image 59814 of 59863
# Downloaded and processed image 59815 of 59863
# Downloaded and processed image 59816 of 59863
# Downloaded and processed image 59817 of 59863
# Downloaded and processed image 59818 of 59863
# Downloaded and processed image 59819 of 59863
# Downloaded and processed image 59820 of 59863
# Downloaded and processed image 59821 of 59863
# Downloaded and processed image 59822 of 59863
# Downloaded and processed image 59823 of 59863
# Downloaded and processed image 59824 of 59863
# Downloaded and processed image 59825 of 59863
# Downloaded and processed image 59826 of 59863
# Downloaded and processed image 59827 of 59863
# Downloaded and processed image 59828 of 59863
# Downloaded and processed image 59829 of 59863
# Downloaded and processed image 59830 of 59863
# Downloaded and processed image 59831 of 59863
# Downloaded and processed image 59832 of 59863
# Downloaded and processed image 59833 of 59863
# Downloaded and processed image 59834 of 59863
# Downloaded and processed image 59835 of 59863
# Downloaded and processed image 59836 of 59863
# Downloaded and processed image 59837 of 59863
# Downloaded and processed image 59838 of 59863
# Downloaded and processed image 59839 of 59863
# Downloaded and processed image 59840 of 59863
# Downloaded and processed image 59841 of 59863
# Downloaded and processed image 59842 of 59863
# Downloaded and processed image 59843 of 59863
# Downloaded and processed image 59844 of 59863
# Downloaded and processed image 59845 of 59863
# Downloaded and processed image 59846 of 59863
# Downloaded and processed image 59847 of 59863
# Downloaded and processed image 59848 of 59863
# Downloaded and processed image 59849 of 59863
# Downloaded and processed image 59850 of 59863
# Downloaded and processed image 59851 of 59863
# Downloaded and processed image 59852 of 59863
# Downloaded and processed image 59853 of 59863
# Downloaded and processed image 59854 of 59863
# Downloaded and processed image 59855 of 59863
# Downloaded and processed image 59856 of 59863
# Downloaded and processed image 59857 of 59863
# Downloaded and processed image 59858 of 59863
# Downloaded and processed image 59859 of 59863
# Downloaded and processed image 59860 of 59863
# Downloaded and processed image 59861 of 59863
# Downloaded and processed image 59862 of 59863
# Downloaded and processed image 59863 of 59863
# Preprocessed image details saved to: Final/Final.csv

# %% [markdown]
# ## TO CONVERT TO ZIP

# %%
import zipfile
import os

def create_zip(folder_path, zip_path):
    # Create a ZIP file
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Iterate over all files and subdirectories in the folder
        for root, _, files in os.walk(folder_path):
            for file in files:
                # Get the full path of the file
                file_path = os.path.join(root, file)
                
                # Add the file to the ZIP
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

# Specify the folder path and ZIP file path
folder_path = '/content/Final'  # Replace with your folder path
zip_path = '/content/Final.zip'  # Replace with the desired ZIP file path

# Create the ZIP file
create_zip(folder_path, zip_path)

# %%
def load_images_from_folder(folder_path):
    images = []
    for filename in os.listdir(folder_path):
        if filename.startswith("preprocessed_"):
            img = cv2.imread(os.path.join(folder_path, filename))
            if img is not None:
                images.append(img)
                print(f"Loaded_{filename}")
    return images

# Folder path where the preprocessed images are stored
folder_path = "Final"

# Load the preprocessed images from the folder
images = load_images_from_folder(folder_path)

# %%
images[0]

# %%
# def find_similar_images(query_image_path, images, filenames, attributes, k=1):
#     query_image = cv2.imread(query_image_path)
#     query_image = cv2.cvtColor(query_image, cv2.COLOR_BGR2RGB)
#     query_image = cv2.resize(query_image, (224, 224))
#     query_image = np.reshape(query_image, (1, -1))

#     reshaped_images = np.reshape(images, (len(images), -1))

#     nbrs = NearestNeighbors(n_neighbors=k).fit(reshaped_images)

#     # Save the NearestNeighbors model
#     joblib.dump(nbrs, 'nearest_neighbors_model.pkl')
#     # Load the NearestNeighbors model
#     nbrs = joblib.load('nearest_neighbors_model.pkl')


#     distances, indices = nbrs.kneighbors(query_image)

#     for i in range(k):
#         index = indices[0][i]
#         filename = filenames[index]
#         matched_attributes = attributes.iloc[index]
        
#         print(f"Similar Image {i+1}: {filename}")
#         print("Attributes:")
#         for attr_name, attr_value in matched_attributes.iteritems():
#             print(f"{attr_name}: {attr_value}")
#         print()

# data = pd.read_csv('Final.csv')
# filenames = data['Filename']
# image_attributes = data[['series_title', 'issue_number', 'issue_comments', 'issue_edition', 'published_date', 'comic_era', 'issue_image', 'issue_image_url']]

# # Find similar images and display attributes
# find_similar_images("bat.jpg", images, filenames, image_attributes)

# %%
def Load_model(images, k=1):

    reshaped_images = np.reshape(images, (len(images), -1))
    nbrs = NearestNeighbors(n_neighbors=k).fit(reshaped_images)
    joblib.dump(nbrs, 'nearest_neighbors_model.pkl')

Load_model(images)

# %%
import pandas as pd
import joblib
import numpy as np
import cv2
import os
from sklearn.neighbors import NearestNeighbors


def find_similar_images(query_image_path, images, filenames, attributes, k=1):
    query_image = cv2.imread(query_image_path)
    query_image = cv2.cvtColor(query_image, cv2.COLOR_BGR2RGB)
    query_image = cv2.resize(query_image, (224, 224))
    query_image = np.reshape(query_image, (1, -1))

    nbrs = joblib.load('nearest_neighbors_model.pkl')
    distances, indices = nbrs.kneighbors(query_image)

    for i in range(k):
        index = indices[0][i]
        filename = filenames[index]
        matched_attributes = attributes.iloc[index]
        
        print(f"Similar Image {i+1}: {filename}")
        print("Attributes:")
        for attr_name, attr_value in matched_attributes.iteritems():
            print(f"{attr_name}: {attr_value}")
        print()

data = pd.read_csv('Final.csv')
filenames = data['Filename']
image_attributes = data[['series_title', 'issue_number', 'issue_comments', 'issue_edition', 'published_date', 'comic_era', 'issue_image', 'issue_image_url']]

# Find similar images and display attributes
find_similar_images("bat.jpg", images, filenames, image_attributes)
